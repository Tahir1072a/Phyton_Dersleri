# %%
import numpy as np
import matplotlib.pyplot as matlob

# %%
maasListesi = np.random.normal(4000,500,1000)
np.mean(maasListesi)
# Out:
# 3998.357263257386

# %%
matlob.hist(maasListesi,50)
matlob.show()
