# %%
import matplotlib.pyplot as plt
import pandas as pd

file_path = r"C:\Users\alica\OneDrive\Masaüstü\study_performance.csv"
my_data = pd.read_csv(file_path)

# %% [markdown]
# ### Boxplot

# %%
# Boxplot elimizdeki verilerde aykırı değerleri bulabileceğimiz bir kutu çizimidir.
# Boxplot veri kümesindeki ortanca değerleri belirler ve bu değerlerin 1.5 katına kadar, alttan ve üstten uzayarak "whis" adlı çizgiler çeker. Bu çizgilerin dışında kalan kısımları "fliers" olarak adlandırır ve bunları aykırı değerlerler olarak işaretler. 

plt.yticks(range(0,101,10)) # yticks bir plot'da y etiketlerini spesifik olarak belirlemek için kullanılır.

plt.boxplot(my_data["math_score"]) # Zorunlu parametre olarak çizdirilecek bir dizi alır.
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x16bcfeb2df0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x16bcfea9790>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x16bcfeb2d90>],
#  'medians': [<matplotlib.lines.Line2D at 0x16bcfea9670>],
#  'fliers': [<matplotlib.lines.Line2D at 0x16bcfea97f0>],
#  'means': []}
